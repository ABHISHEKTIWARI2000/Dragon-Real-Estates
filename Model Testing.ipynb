# %% [markdown]
# # Using the Model

# %%
from joblib import load
import numpy as np
model = load('Dragon_real_estates.joblib')

# %%
input = np.array([[-0.44228927, -0.4898311 , -1.37640684, -0.27288841, -0.34321545,
        0.32338857, -0.33092752,  1.20235683, -1.0016859 ,  0.05733231,
       -1.21003475,  0.38110555, -0.57309194]])
model.predict(input)
# Out:
# array([23.329])
