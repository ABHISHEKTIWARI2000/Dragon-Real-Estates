# %% [markdown]
# # Using the Model

# %%
from joblib import load
import numpy as np
model = load('Dragon_real_estates.joblib')

# %%
input = np.array([[-0.43169386, -0.4898311 ,  0.37049623,  3.66450153, -0.06907906,
       -0.46045858,  0.87729603, -0.40874167, -0.5429938 , -0.80932303,
       -0.97491834,  0.45343469,  0.70963717]])
model.predict(input)
# Out:
# array([20.265])
